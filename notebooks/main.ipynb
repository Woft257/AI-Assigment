# %% [markdown]
# # AI Introduction - Bài Tập Lớn
# ## [TÊN ĐỀ TÀI]
#
# ---

# %% [markdown]
# ## 1. Giới thiệu
#
# Mô tả bài toán thực tế...

# %% [markdown]
# ## 2. Cài đặt thư viện

# %%
# Import modules từ thư mục modules
import sys
sys.path.append('/content/modules')

import numpy as np
import pandas as pd
# Thêm các thư viện khác nếu cần

# %% [markdown]
# ## 3. Tải dữ liệu

# %%
# TODO: Thay link dữ liệu thực tế
# !wget -q [LINK_DU_LIEU] -O data.zip
# !unzip -q data.zip
print("Đã tải dữ liệu thành công")

# %% [markdown]
# ## 4. (A) Tìm kiếm - Search

# %%
# TODO: Implement Search (BFS/DFS/A*)
# from modules.search import Problem, bfs, a_star_search

# Định nghĩa state, actions, goal, cost
# Chạy thuật toán tìm kiếm

# %% [markdown]
# ## 5. (B) Heuristic / CSP

# %%
# TODO: Implement Heuristic hoặc CSP
# from modules.heuristic_csp import hill_climbing, CSP

# Định nghĩa heuristic function
# Hoặc định nghĩa CSP với variables, domains, constraints

# %% [markdown]
# ## 6. (C) Suy luận tri thức - Knowledge Representation

# %%
# TODO: Implement Knowledge Representation
# from modules.knowledge import KB, Rule, forward_chaining

# Định nghĩa facts và rules
# Sử dụng propositional logic hoặc IF-THEN rules

# %% [markdown]
# ## 7. (D) Bayes / Xác suất

# %%
# TODO: Implement Bayesian Network hoặc Naive Bayes
# from modules.bayes import NaiveBayesClassifier, BayesianNetwork

# Train và sử dụng model để suy luận với uncertainty

# %% [markdown]
# ## 8. (E) Học máy - Machine Learning

# %%
# TODO: Implement ML (Naive Bayes, Decision Tree, Perceptron)
# from modules.machine_learning import Perceptron, DecisionTree, train_test_split, accuracy_score

# Train model và đánh giá

# %% [markdown]
# ## 9. Tích hợp hệ thống

# %%
# TODO: Kết hợp các thành phần AI
# Data -> Search/ML/Inference -> Decision

# %% [markdown]
# ## 10. Kết luận
